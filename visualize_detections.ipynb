# %%
import pathlib
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is D8AA-C9FC
#
#  Directory of C:\Users\ville\Projects\adversarial_examples\coco_foolbox
#
# 15.07.2021  15.41    <DIR>          .
# 15.07.2021  15.41    <DIR>          ..
# 14.07.2021  13.04                31 .gitignore
# 15.07.2021  13.53    <DIR>          .ipynb_checkpoints
# 09.07.2021  11.52    <DIR>          annotations
# 13.07.2021  11.22    <DIR>          backups
# 09.07.2021  14.57         1ÿ099ÿ358 coco_foolbox_crafting_adversarial_images_224x224.ipynb
# 09.07.2021  16.15         8ÿ477ÿ014 coco_foolbox_crafting_adversarial_images_224x224_fgsm.ipynb
# 06.07.2021  14.39        10ÿ247ÿ039 coco_foolbox_draft_version.ipynb
# 06.07.2021  20.36         4ÿ876ÿ392 coco_foolbox_notebook_for_solving_data_errors.ipynb
# 14.07.2021  12.51    <DIR>          datasets
# 14.07.2021  21.30    <DIR>          dataset_tools
# 14.07.2021  13.03    <DIR>          evaluation
# 14.07.2021  13.06    <DIR>          models
# ...

# %%
data_dir = pathlib.Path('./datasets')

# %%
image_count = len(list(data_dir.glob('*/data/*.jpg*')))
print(image_count)
# Out:
# 20000

# %%
coco_original = list(data_dir.glob('coco_original/data/*'))
PIL.Image.open(str(coco_original[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426 at 0x28918327B50>

# %%
coco_small = list(data_dir.glob('coco_224/data/*'))
PIL.Image.open(str(coco_small[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x2891830F850>

# %%
fgsm = list(data_dir.glob('adv_data_fgsm/data/*'))
PIL.Image.open(str(fgsm[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x289182DE910>

# %%
pgd = list(data_dir.glob('adv_data_pgd/data/*'))
PIL.Image.open(str(pgd[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x289182DEA30>
